# %% [markdown]
# # Explore the dataset
#
#
# In this notebook, we will perform an EDA (Exploratory Data Analysis) on the processed Waymo dataset (data in the `processed` folder). In the first part, you will create a function to display

# %%
import glob
import numpy as np
from utils import get_dataset

import matplotlib.pyplot as plt
import matplotlib.patches as patches
# %matplotlib inline

# %%
dataset = get_dataset("./data/processed/segment-11355519273066561009_5323_000_5343_000_with_camera_labels.tfrecord")
# Out:
# INFO:tensorflow:Reading unweighted datasets: ['./data/processed/segment-11355519273066561009_5323_000_5343_000_with_camera_labels.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['./data/processed/segment-11355519273066561009_5323_000_5343_000_with_camera_labels.tfrecord']
# INFO:tensorflow:Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/object_detection/builders/dataset_builder.py:105: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_deterministic`.
# ...

# %% [markdown]
# ## Write a function to display an image and the bounding boxes
#
# Implement the `display_instances` function below. This function takes a batch as an input and display an image with its corresponding bounding boxes. The only requirement is that the classes should be color coded (eg, vehicles in red, pedestrians in blue, cyclist in green).

# %%
def display_instances(batch):
    """
    This function takes a batch from the dataset and display the image with 
    the associated bounding boxes.
    """
    # ADD CODE HERE
    mapping = {1: 'vehicle', 2: 'pedestrian', 4: 'cyclist'}
    
    # color mapping
    brown = '#a52a2a'
    blueviolet = '#8a2be2'
    darkblue = '#00008b'
    
    color_map = {1 : brown, 2 : blueviolet, 4 : darkblue}
    
    # setting boxes
    file_name = batch['filename'].numpy().decode('utf-8')
    image = batch['image'].numpy()
    classes = batch['groundtruth_classes'].numpy()
    bboxes = batch['groundtruth_boxes'].numpy()
    
    # unnormalizing the boxes for plotting
    f, ax = plt.subplots(4, 5, figsize=(20, 10))
    
    for cl, bb in zip(classes, bboxes):
        y1, x1, y2, x2 = bb
        rec = Rectangle((x1, y1), x2- x1, y2-y1, facecolor='none', edgecolor=colormap[cl])
        ax.add_patch(rec)
    
    plt.axis('off')

# %% [markdown]
# ## Display 10 images
#
# Using the dataset created in the second cell and the function you just coded, display 10 random images with the associated bounding boxes. You can use the methods `take` and `shuffle` on the dataset.

# %%
## STUDENT SOLUTION HERE
for i in range(4):
    for image in dataset.take(i+1):
        display_instances(image)
        
plt.figure(figsize=(10, 10))        
plt.show()

# %% [markdown]
# ## Additional EDA
#
# In this last part, you are free to perform any additional analysis of the dataset. What else would like to know about the data?
# For example, think about data distribution. So far, you have only looked at a single file...
